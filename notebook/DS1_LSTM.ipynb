# %% [markdown]
# # CNN-LSTM — Heart Disease Prediction
#
# > **Architecture**: CNN-LSTM Hybrid — Al Reshan et al. (2023)
# > *18 Conv layers · 12 Pooling layers · 1 LSTM layer · 1 FC layer · Softmax output*
#
# **Dataset**: `heart_statlog_cleveland_hungary_final.csv` — Dataset II (1190 → 1,200 rows after augmentation)
# **Task**: Binary classification (0 = No HD, 1 = HD)
# **Features**: All 11 ETC-ranked features from paper Table 2
#
# Same preprocessing pipeline as `DS2_ANN_96_.ipynb` — identical augmentation, split, and scaling.

# %% [markdown]
# ## 1. Imports & Reproducibility

# %%
import os, random, warnings, math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns

from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.preprocessing import RobustScaler
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import (
    accuracy_score, roc_auc_score, f1_score,
    matthews_corrcoef, confusion_matrix,
    classification_report, roc_curve
)
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers, callbacks
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, MaxPooling2D, Dropout,
    Dense, LSTM, Reshape
)

warnings.filterwarnings('ignore')
SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED); np.random.seed(SEED); tf.random.set_seed(SEED)
print('TensorFlow version:', tf.__version__)
# Out:
# TensorFlow version: 2.19.0

# %% [markdown]
# ## 2. Load Dataset & Feature Selection
#
# Features ordered by Extra Tree Classifier importance (paper Table 2).

# %%
CSV_PATH = r"C:\Users\Administrator\Downloads\processed_cleveland (1).csv"
df = pd.read_csv(CSV_PATH)

df = pd.read_csv("processed_cleveland (1).csv")

# Assign proper column names
df.columns = [
    'age', 'sex', 'chest pain type', 'resting bp s', 'cholesterol',
    'fasting blood sugar', 'resting ecg', 'max heart rate',
    'exercise angina', 'oldpeak', 'ST slope',
    'num_major_vessels', 'thal', 'target'
]

# Handle missing values ("?")
df.replace('?', np.nan, inplace=True)
df = df.astype(float)
df.fillna(df.median(), inplace=True)

# Convert to binary classification
df['target'] = df['target'].apply(lambda x: 1 if x > 0 else 0)
print(f'Dataset shape : {df.shape}')
df.head()

FEATURE_COLS = [
    'ST slope',
    'chest pain type',
    'exercise angina',
    'max heart rate',
    'cholesterol',
    'oldpeak',
    'age',
    'resting bp s',
    'sex',
    'resting ecg',
    'fasting blood sugar'
]

# Keep only required columns
df = df[FEATURE_COLS + ['target']]
# Out:
# Dataset shape : (303, 14)

# %% [markdown]
# ## 3. Data Augmentation (1190 -> 5,000 rows)
#
# Four strategies — Gaussian noise, SMOTE interpolation, feature swap, boundary perturbation —
# applied class-proportionally to reach the target size.

# %%
TARGET_ROWS = 5000

FEAT_TYPE = {
    'ST slope': 'cat',
    'chest pain type': 'cat',
    'exercise angina': 'binary',
    'max heart rate': 'num',
    'cholesterol': 'num',
    'oldpeak': 'num',
    'age': 'num',
    'resting bp s': 'num',
    'sex': 'binary',
    'resting ecg': 'cat',
    'fasting blood sugar': 'binary'
}

BINARY_COLS = [f for f, t in FEAT_TYPE.items() if t == 'binary']
CAT_COLS    = [f for f, t in FEAT_TYPE.items() if t == 'cat']
NUM_COLS    = [f for f, t in FEAT_TYPE.items() if t == 'num']
CLIP = {
    'age':           (20,  90),
    'resting bp s':  (80,  220),
    'cholesterol':   (100, 600),
    'max heart rate':(60,  210),
    'oldpeak':       (0.0, 6.5),
}

CAT_LEVELS = {
    'chest pain type':     [1, 2, 3, 4],
    'resting ecg':         [0, 1, 2],
    'ST slope':            [1, 2, 3],
    'sex':                 [0, 1],
    'fasting blood sugar': [0, 1],
    'exercise angina':     [0, 1],
}

def empty_aug_df():
    return pd.DataFrame(columns=FEATURE_COLS + ['target'])

def postprocess(df_syn):
    df_syn = df_syn.copy()
    if df_syn.empty:
        return empty_aug_df()
    for col in FEATURE_COLS + ['target']:
        if col not in df_syn.columns:
            df_syn[col] = 0
    for col in BINARY_COLS + CAT_COLS:
        df_syn[col] = df_syn[col].round().astype(int)
    for col, (lo, hi) in CLIP.items():
        df_syn[col] = df_syn[col].clip(lo, hi)
    for col in NUM_COLS:
        df_syn[col] = df_syn[col].round(1) if col == 'oldpeak' else df_syn[col].round().astype(int)
    for col, levels in CAT_LEVELS.items():
        df_syn[col] = df_syn[col].clip(min(levels), max(levels)).round().astype(int)
    return df_syn

def gaussian_noise_augment(df_class, n_samples):
    if n_samples <= 0:
        return empty_aug_df()
    rng   = np.random.default_rng(SEED)
    idx   = rng.integers(0, len(df_class), size=n_samples)
    synth = df_class.iloc[idx][FEATURE_COLS].copy().reset_index(drop=True)
    for col in NUM_COLS:
        iqr = df_class[col].quantile(0.75) - df_class[col].quantile(0.25)
        std = max(iqr * 0.02, 0.01)
        synth[col] = synth[col] + rng.normal(0, std, n_samples)
    synth['target'] = int(df_class['target'].iloc[0])
    return postprocess(synth)

def smote_interpolate(df_class, n_samples, k=5):
    if n_samples <= 0:
        return empty_aug_df()
    rng        = np.random.default_rng(SEED + 1)
    X          = df_class[NUM_COLS].values
    Xs         = RobustScaler().fit_transform(X)
    nbrs       = NearestNeighbors(n_neighbors=k+1).fit(Xs)
    _, indices = nbrs.kneighbors(Xs)
    base_idx   = rng.integers(0, len(df_class), size=n_samples)
    alpha      = rng.uniform(0, 1, size=n_samples)
    rows = []
    for i, a in zip(base_idx, alpha):
        neigh_idx = indices[i, rng.integers(1, k+1)]
        row       = df_class.iloc[i][FEATURE_COLS].copy()
        neigh_row = df_class.iloc[neigh_idx][FEATURE_COLS].copy()
        for col in NUM_COLS:
            row[col] = row[col] + a * (neigh_row[col] - row[col])
        row['target'] = int(df_class['target'].iloc[i])
        rows.append(row)
    return postprocess(pd.DataFrame(rows).reset_index(drop=True))

def feature_swap_augment(df_class, n_samples):
    if n_samples <= 0:
        return empty_aug_df()
    rng  = np.random.default_rng(SEED + 2)
    n    = len(df_class)
    rows = []
    for _ in range(n_samples):
        i = rng.integers(0, n)
        j = rng.integers(0, n)
        while j == i:
            j = rng.integers(0, n)
        row_i     = df_class.iloc[i][FEATURE_COLS].copy()
        row_j     = df_class.iloc[j][FEATURE_COLS].copy()
        n_swap    = rng.integers(max(1, int(len(NUM_COLS)*0.3)),
                                  max(2, int(len(NUM_COLS)*0.7))+1)
        swap_cols = rng.choice(NUM_COLS, size=n_swap, replace=False)
        for col in swap_cols:
            row_i[col], row_j[col] = row_j[col], row_i[col]
        row_i['target'] = int(df_class['target'].iloc[i])
        rows.append(row_i)
    return postprocess(pd.DataFrame(rows).reset_index(drop=True))

def boundary_perturbation(df_pos, df_neg, target_label, n_samples):
    if n_samples <= 0:
        return empty_aug_df()
    rng      = np.random.default_rng(SEED + 3)
    src      = df_pos if target_label == 1 else df_neg
    opposite = df_neg if target_label == 1 else df_pos
    X_src    = src[NUM_COLS].values
    X_opp    = opposite[NUM_COLS].values
    scaler   = RobustScaler()
    all_Xs   = scaler.fit_transform(np.vstack([X_src, X_opp]))
    X_src_s  = all_Xs[:len(X_src)]
    X_opp_s  = all_Xs[len(X_src):]
    nbrs     = NearestNeighbors(n_neighbors=3).fit(X_opp_s)
    _, indices = nbrs.kneighbors(X_src_s)
    base_idx = rng.integers(0, len(src), size=n_samples)
    alpha    = rng.uniform(0.1, 0.4, size=n_samples)
    rows = []
    for i, a in zip(base_idx, alpha):
        opp_idx = indices[i, rng.integers(0, 3)]
        row     = src.iloc[i][FEATURE_COLS].copy()
        opp_row = opposite.iloc[opp_idx][FEATURE_COLS].copy()
        for col in NUM_COLS:
            row[col] = row[col] + a * (opp_row[col] - row[col])
        row['target'] = target_label
        rows.append(row)
    return postprocess(pd.DataFrame(rows).reset_index(drop=True))

def split_quota(n):
    base = n // 4
    rem  = n % 4
    return [base + (1 if i < rem else 0) for i in range(4)]

# Augment full dataset first, then split
df_pos = df[df['target'] == 1].reset_index(drop=True)
df_neg = df[df['target'] == 0].reset_index(drop=True)
n_orig = len(df)
n_to_gen = max(0, TARGET_ROWS - n_orig)
pos_ratio = len(df_pos) / n_orig if n_orig > 0 else 0.5
n_gen_pos = int(n_to_gen * pos_ratio)
n_gen_neg = n_to_gen - n_gen_pos

pq = split_quota(n_gen_pos)
nq = split_quota(n_gen_neg)

parts = [
    gaussian_noise_augment(df_pos, pq[0]),
    gaussian_noise_augment(df_neg, nq[0]),
    smote_interpolate(df_pos, pq[1]),
    smote_interpolate(df_neg, nq[1]),
    feature_swap_augment(df_pos, pq[2]),
    feature_swap_augment(df_neg, nq[2]),
    boundary_perturbation(df_pos, df_neg, 1, pq[3]),
    boundary_perturbation(df_pos, df_neg, 0, nq[3]),
]

aug_df = pd.concat([df] + parts, ignore_index=True)
aug_df = aug_df.sample(frac=1, random_state=SEED).reset_index(drop=True)

for col in BINARY_COLS + CAT_COLS + ['target']:
    aug_df[col] = aug_df[col].astype(int)

X_raw = aug_df[FEATURE_COLS].values
y = aug_df['target'].values

X_train, X_test, y_train, y_test = train_test_split(
    X_raw, y, test_size=0.20, random_state=SEED, stratify=y
)

scaler = RobustScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print(f'Original rows       : {n_orig}')
print(f'Augmented rows      : {len(aug_df)} (target={TARGET_ROWS})')
print(f'Holdout test rows   : {len(y_test)}')
print(f'Class dist train    : {np.bincount(y_train.astype(int))}')
print(f'Class dist test     : {np.bincount(y_test.astype(int))}')
print(f'Train shape         : {X_train_scaled.shape}')
print(f'Test  shape         : {X_test_scaled.shape}')
# Out:
# Original rows       : 303
# Augmented rows      : 5000 (target=5000)
# Holdout test rows   : 1000
# Class dist train    : [2166 1834]
# Class dist test     : [541 459]
# Train shape         : (4000, 11)
# Test  shape         : (1000, 11)

# %% [markdown]
# ## 4. Reshape Tabular Features -> LSTM Input
#
# Prepare tabular data as sequences for LSTM:
#
# 11 features are reshaped to `(N, 11, 1)` where each feature is treated as a timestep.

# %%
# ── Reshape tabular features for LSTM input ───────────────────────────────────
n_features = X_train_scaled.shape[1]  # 11

X_train_lstm = X_train_scaled.reshape(X_train_scaled.shape[0], n_features, 1)
X_test_lstm  = X_test_scaled.reshape(X_test_scaled.shape[0], n_features, 1)

print(f'Train LSTM shape : {X_train_lstm.shape}')
print(f'Test  LSTM shape : {X_test_lstm.shape}')
# Out:
# Train LSTM shape : (4000, 11, 1)
# Test  LSTM shape : (1000, 11, 1)

# %% [markdown]
# ## 5. Build LSTM Model
#
# Stacked LSTM architecture for binary heart disease classification.

# %%
def build_lstm_model(input_shape, num_classes=2, lr=1e-3):
    model = keras.Sequential([
        Input(shape=input_shape),
        LSTM(128, return_sequences=True, dropout=0.25, recurrent_dropout=0.1),
        LSTM(64, dropout=0.25, recurrent_dropout=0.1),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(num_classes, activation='softmax')
    ])

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=lr),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy', keras.metrics.AUC(name='auc')]
    )
    return model

lstm_model = build_lstm_model(input_shape=X_train_lstm.shape[1:], num_classes=2, lr=1e-3)
model = lstm_model
lstm_model.summary()
print(f'\nTotal trainable parameters: {lstm_model.count_params():,}')
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 11, 128)        │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 120,258 (469.76 KB)
#  Trainable params: 120,258 (469.76 KB)
#  Non-trainable params: 0 (0.00 B)
# Total trainable parameters: 120,258

# %% [markdown]
# ## 6. Callbacks — Cosine LR + EarlyStopping + ReduceLROnPlateau + ModelCheckpoint

# %%
def cosine_lr(epoch, total=300, lr_start=1e-4, lr_min=1e-7):
    return lr_min + 0.5 * (lr_start - lr_min) * (1 + math.cos(math.pi * epoch / total))

def get_callbacks(name, patience_es=35, patience_lr=20, total_epochs=300, lr_start=1e-4):
    return [
        callbacks.EarlyStopping(
            monitor='val_auc', patience=patience_es,
            restore_best_weights=True, mode='max',
            min_delta=1e-4, verbose=1
        ),
        callbacks.LearningRateScheduler(
            lambda epoch: cosine_lr(epoch, total_epochs, lr_start), verbose=0
        ),
        callbacks.ReduceLROnPlateau(
            monitor='val_auc', factor=0.5, patience=patience_lr,
            min_lr=1e-8, mode='max', verbose=1
        ),
        callbacks.ModelCheckpoint(
            filepath=f'{name}_best.weights.h5', monitor='val_auc',
            save_best_only=True, save_weights_only=True,
            mode='max', verbose=0
        ),
    ]

# %% [markdown]
# ## 7. Train LSTM

# %%
TOTAL_EPOCHS = 220

# Recompile without AUC metric to avoid Keras segment_ids bug in this environment
lstm_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
 )

neg, pos = np.bincount(y_train.astype(int))
class_weight = {0: 1.0, 1: neg / pos}
print(f'Class weights : {class_weight}')
print(f'Train samples : {X_train_lstm.shape[0]}')
print('Training LSTM ...')

train_callbacks = [
    callbacks.EarlyStopping(
        monitor='val_accuracy', patience=25,
        restore_best_weights=True, mode='max',
        min_delta=1e-4, verbose=1
    ),
    callbacks.ReduceLROnPlateau(
        monitor='val_accuracy', factor=0.5, patience=8,
        min_lr=1e-6, mode='max', verbose=1
    ),
    callbacks.ModelCheckpoint(
        filepath='lstm_best.weights.h5', monitor='val_accuracy',
        save_best_only=True, save_weights_only=True,
        mode='max', verbose=0
    ),
]

history = lstm_model.fit(
    X_train_lstm,
    y_train,
    validation_split=0.20,
    epochs=TOTAL_EPOCHS,
    batch_size=32,
    class_weight=class_weight,
    callbacks=train_callbacks,
    verbose=1
)
# Out:
# Class weights : {0: 1.0, 1: np.float64(1.1810250817884405)}
# Train samples : 4000
# Training LSTM ...
# Epoch 1/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6492 - loss: 0.6706 - val_accuracy: 0.7525 - val_loss: 0.5475 - learning_rate: 0.0010
# Epoch 2/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6875 - loss: 0.6326 - val_accuracy: 0.7700 - val_loss: 0.5254 - learning_rate: 0.0010
# Epoch 3/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6804 - loss: 0.6302 - val_accuracy: 0.7663 - val_loss: 0.5306 - learning_rate: 0.0010
# Epoch 4/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6853 - loss: 0.6182 - val_accuracy: 0.7775 - val_loss: 0.5150 - learning_rate: 0.0010
# Epoch 5/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6852 - loss: 0.6175 - val_accuracy: 0.7550 - val_loss: 0.4736 - learning_rate: 0.0010
# Epoch 6/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6980 - loss: 0.5921 - val_accuracy: 0.7663 - val_loss: 0.4632 - learning_rate: 0.0010
# Epoch 7/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6842 - loss: 0.5830 - val_accuracy: 0.7862 - val_loss: 0.4448 - learning_rate: 0.0010
# Epoch 8/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7047 - loss: 0.5768 - val_accuracy: 0.7800 - val_loss: 0.4439 - learning_rate: 0.0010
# Epoch 9/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7191 - loss: 0.5783 - val_accuracy: 0.7800 - val_loss: 0.4412 - learning_rate: 0.0010
# Epoch 10/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7286 - loss: 0.5623 - val_accuracy: 0.7425 - val_loss: 0.4711 - learning_rate: 0.0010
# Epoch 11/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7249 - loss: 0.5457 - val_accuracy: 0.7775 - val_loss: 0.4352 - learning_rate: 0.0010
# Epoch 12/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7463 - loss: 0.5287 - val_accuracy: 0.7862 - val_loss: 0.4275 - learning_rate: 0.0010
# Epoch 13/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7516 - loss: 0.5199 - val_accuracy: 0.7900 - val_loss: 0.4213 - learning_rate: 0.0010
# Epoch 14/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7603 - loss: 0.5154 - val_accuracy: 0.7987 - val_loss: 0.4167 - learning_rate: 0.0010
# Epoch 15/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7458 - loss: 0.5165 - val_accuracy: 0.7900 - val_loss: 0.4258 - learning_rate: 0.0010
# Epoch 16/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7568 - loss: 0.5092 - val_accuracy: 0.7837 - val_loss: 0.4451 - learning_rate: 0.0010
# Epoch 17/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7592 - loss: 0.5147 - val_accuracy: 0.8163 - val_loss: 0.4045 - learning_rate: 0.0010
# Epoch 18/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7615 - loss: 0.5051 - val_accuracy: 0.8112 - val_loss: 0.3989 - learning_rate: 0.0010
# Epoch 19/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7726 - loss: 0.5170 - val_accuracy: 0.8125 - val_loss: 0.3945 - learning_rate: 0.0010
# Epoch 20/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7953 - loss: 0.4786 - val_accuracy: 0.8238 - val_loss: 0.3718 - learning_rate: 0.0010
# Epoch 21/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7909 - loss: 0.4574 - val_accuracy: 0.8363 - val_loss: 0.3638 - learning_rate: 0.0010
# Epoch 22/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7954 - loss: 0.4511 - val_accuracy: 0.8250 - val_loss: 0.3489 - learning_rate: 0.0010
# Epoch 23/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7997 - loss: 0.4462 - val_accuracy: 0.8350 - val_loss: 0.3484 - learning_rate: 0.0010
# Epoch 24/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8101 - loss: 0.4309 - val_accuracy: 0.8263 - val_loss: 0.3538 - learning_rate: 0.0010
# Epoch 25/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8163 - loss: 0.4008 - val_accuracy: 0.8338 - val_loss: 0.3416 - learning_rate: 0.0010
# Epoch 26/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8129 - loss: 0.4187 - val_accuracy: 0.8487 - val_loss: 0.3329 - learning_rate: 0.0010
# Epoch 27/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8360 - loss: 0.4011 - val_accuracy: 0.8400 - val_loss: 0.3328 - learning_rate: 0.0010
# Epoch 28/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8283 - loss: 0.3966 - val_accuracy: 0.8475 - val_loss: 0.3282 - learning_rate: 0.0010
# Epoch 29/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8500 - loss: 0.3787 - val_accuracy: 0.8675 - val_loss: 0.3019 - learning_rate: 0.0010
# Epoch 30/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8552 - loss: 0.3586 - val_accuracy: 0.8413 - val_loss: 0.3257 - learning_rate: 0.0010
# Epoch 31/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8449 - loss: 0.3767 - val_accuracy: 0.8575 - val_loss: 0.2894 - learning_rate: 0.0010
# Epoch 32/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8523 - loss: 0.3639 - val_accuracy: 0.8925 - val_loss: 0.2866 - learning_rate: 0.0010
# Epoch 33/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8561 - loss: 0.3518 - val_accuracy: 0.8975 - val_loss: 0.2839 - learning_rate: 0.0010
# Epoch 34/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8524 - loss: 0.3401 - val_accuracy: 0.8687 - val_loss: 0.2878 - learning_rate: 0.0010
# Epoch 35/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8624 - loss: 0.3337 - val_accuracy: 0.8863 - val_loss: 0.2606 - learning_rate: 0.0010
# Epoch 36/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8594 - loss: 0.3177 - val_accuracy: 0.8950 - val_loss: 0.2717 - learning_rate: 0.0010
# Epoch 37/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8641 - loss: 0.3135 - val_accuracy: 0.8737 - val_loss: 0.2831 - learning_rate: 0.0010
# Epoch 38/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8618 - loss: 0.3239 - val_accuracy: 0.9125 - val_loss: 0.2469 - learning_rate: 0.0010
# Epoch 39/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8734 - loss: 0.2940 - val_accuracy: 0.9087 - val_loss: 0.2526 - learning_rate: 0.0010
# Epoch 40/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8737 - loss: 0.3023 - val_accuracy: 0.9100 - val_loss: 0.2458 - learning_rate: 0.0010
# Epoch 41/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8803 - loss: 0.2717 - val_accuracy: 0.8975 - val_loss: 0.2505 - learning_rate: 0.0010
# Epoch 42/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8971 - loss: 0.2459 - val_accuracy: 0.9038 - val_loss: 0.2635 - learning_rate: 0.0010
# Epoch 43/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8941 - loss: 0.2545 - val_accuracy: 0.9150 - val_loss: 0.2770 - learning_rate: 0.0010
# Epoch 44/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8934 - loss: 0.2620 - val_accuracy: 0.8863 - val_loss: 0.2840 - learning_rate: 0.0010
# Epoch 45/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8969 - loss: 0.2486 - val_accuracy: 0.9025 - val_loss: 0.2327 - learning_rate: 0.0010
# Epoch 46/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8941 - loss: 0.2468 - val_accuracy: 0.9150 - val_loss: 0.2106 - learning_rate: 0.0010
# Epoch 47/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9095 - loss: 0.2374 - val_accuracy: 0.9200 - val_loss: 0.2497 - learning_rate: 0.0010
# Epoch 48/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9011 - loss: 0.2334 - val_accuracy: 0.9087 - val_loss: 0.2517 - learning_rate: 0.0010
# Epoch 49/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9042 - loss: 0.2321 - val_accuracy: 0.9250 - val_loss: 0.2238 - learning_rate: 0.0010
# Epoch 50/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9053 - loss: 0.2227 - val_accuracy: 0.9212 - val_loss: 0.2303 - learning_rate: 0.0010
# Epoch 51/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9083 - loss: 0.2256 - val_accuracy: 0.9175 - val_loss: 0.2219 - learning_rate: 0.0010
# Epoch 52/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9114 - loss: 0.2182 - val_accuracy: 0.9300 - val_loss: 0.1866 - learning_rate: 0.0010
# Epoch 53/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9089 - loss: 0.2250 - val_accuracy: 0.9262 - val_loss: 0.2254 - learning_rate: 0.0010
# Epoch 54/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9201 - loss: 0.1981 - val_accuracy: 0.9237 - val_loss: 0.2440 - learning_rate: 0.0010
# Epoch 55/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9303 - loss: 0.1769 - val_accuracy: 0.9200 - val_loss: 0.2231 - learning_rate: 0.0010
# Epoch 56/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9185 - loss: 0.2039 - val_accuracy: 0.9237 - val_loss: 0.2061 - learning_rate: 0.0010
# Epoch 57/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9218 - loss: 0.1905 - val_accuracy: 0.9287 - val_loss: 0.2319 - learning_rate: 0.0010
# Epoch 58/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9011 - loss: 0.2244 - val_accuracy: 0.9362 - val_loss: 0.1974 - learning_rate: 0.0010
# Epoch 59/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9202 - loss: 0.1926 - val_accuracy: 0.9287 - val_loss: 0.2269 - learning_rate: 0.0010
# Epoch 60/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9260 - loss: 0.1767 - val_accuracy: 0.9250 - val_loss: 0.2134 - learning_rate: 0.0010
# Epoch 61/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9219 - loss: 0.1885 - val_accuracy: 0.9388 - val_loss: 0.2004 - learning_rate: 0.0010
# Epoch 62/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9235 - loss: 0.1891 - val_accuracy: 0.9250 - val_loss: 0.2288 - learning_rate: 0.0010
# Epoch 63/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9212 - loss: 0.1928 - val_accuracy: 0.9400 - val_loss: 0.1909 - learning_rate: 0.0010
# Epoch 64/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9300 - loss: 0.1734 - val_accuracy: 0.9312 - val_loss: 0.2144 - learning_rate: 0.0010
# Epoch 65/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9383 - loss: 0.1633 - val_accuracy: 0.9375 - val_loss: 0.2092 - learning_rate: 0.0010
# Epoch 66/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9147 - loss: 0.1989 - val_accuracy: 0.9425 - val_loss: 0.1953 - learning_rate: 0.0010
# Epoch 67/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9264 - loss: 0.1808 - val_accuracy: 0.9463 - val_loss: 0.1757 - learning_rate: 0.0010
# Epoch 68/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9273 - loss: 0.1661 - val_accuracy: 0.9475 - val_loss: 0.1630 - learning_rate: 0.0010
# Epoch 69/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9369 - loss: 0.1705 - val_accuracy: 0.9438 - val_loss: 0.1851 - learning_rate: 0.0010
# Epoch 70/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9348 - loss: 0.1585 - val_accuracy: 0.9350 - val_loss: 0.2081 - learning_rate: 0.0010
# Epoch 71/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9280 - loss: 0.1711 - val_accuracy: 0.9337 - val_loss: 0.2339 - learning_rate: 0.0010
# Epoch 72/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9366 - loss: 0.1586 - val_accuracy: 0.9300 - val_loss: 0.2228 - learning_rate: 0.0010
# Epoch 73/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9397 - loss: 0.1454 - val_accuracy: 0.9488 - val_loss: 0.1808 - learning_rate: 0.0010
# Epoch 74/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9339 - loss: 0.1446 - val_accuracy: 0.9425 - val_loss: 0.1935 - learning_rate: 0.0010
# Epoch 75/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9395 - loss: 0.1524 - val_accuracy: 0.9350 - val_loss: 0.2400 - learning_rate: 0.0010
# Epoch 76/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9330 - loss: 0.1759 - val_accuracy: 0.9375 - val_loss: 0.1986 - learning_rate: 0.0010
# Epoch 77/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9259 - loss: 0.1705 - val_accuracy: 0.9388 - val_loss: 0.1815 - learning_rate: 0.0010
# Epoch 78/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9443 - loss: 0.1445 - val_accuracy: 0.9312 - val_loss: 0.1998 - learning_rate: 0.0010
# Epoch 79/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9347 - loss: 0.1635 - val_accuracy: 0.9375 - val_loss: 0.1983 - learning_rate: 0.0010
# Epoch 80/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9441 - loss: 0.1438 - val_accuracy: 0.9400 - val_loss: 0.2233 - learning_rate: 0.0010
# Epoch 81/220
#  93/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9465 - loss: 0.1448
# Epoch 81: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9463 - loss: 0.1448 - val_accuracy: 0.9438 - val_loss: 0.1917 - learning_rate: 0.0010
# Epoch 82/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9457 - loss: 0.1270 - val_accuracy: 0.9325 - val_loss: 0.2242 - learning_rate: 5.0000e-04
# Epoch 83/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9389 - loss: 0.1602 - val_accuracy: 0.9400 - val_loss: 0.2089 - learning_rate: 5.0000e-04
# Epoch 84/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9475 - loss: 0.1276 - val_accuracy: 0.9413 - val_loss: 0.1970 - learning_rate: 5.0000e-04
# Epoch 85/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9484 - loss: 0.1380 - val_accuracy: 0.9375 - val_loss: 0.2031 - learning_rate: 5.0000e-04
# Epoch 86/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9428 - loss: 0.1277 - val_accuracy: 0.9400 - val_loss: 0.2095 - learning_rate: 5.0000e-04
# Epoch 87/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9482 - loss: 0.1224 - val_accuracy: 0.9463 - val_loss: 0.1942 - learning_rate: 5.0000e-04
# Epoch 88/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9594 - loss: 0.1076 - val_accuracy: 0.9400 - val_loss: 0.2260 - learning_rate: 5.0000e-04
# Epoch 89/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9506 - loss: 0.1220 - val_accuracy: 0.9513 - val_loss: 0.2061 - learning_rate: 5.0000e-04
# Epoch 90/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9469 - loss: 0.1381 - val_accuracy: 0.9525 - val_loss: 0.2100 - learning_rate: 5.0000e-04
# Epoch 91/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9492 - loss: 0.1301 - val_accuracy: 0.9488 - val_loss: 0.2208 - learning_rate: 5.0000e-04
# Epoch 92/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9467 - loss: 0.1155 - val_accuracy: 0.9488 - val_loss: 0.2203 - learning_rate: 5.0000e-04
# Epoch 93/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9500 - loss: 0.1193 - val_accuracy: 0.9488 - val_loss: 0.2171 - learning_rate: 5.0000e-04
# Epoch 94/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9459 - loss: 0.1336 - val_accuracy: 0.9438 - val_loss: 0.2231 - learning_rate: 5.0000e-04
# Epoch 95/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9455 - loss: 0.1221 - val_accuracy: 0.9438 - val_loss: 0.2374 - learning_rate: 5.0000e-04
# Epoch 96/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9496 - loss: 0.1186 - val_accuracy: 0.9438 - val_loss: 0.2161 - learning_rate: 5.0000e-04
# Epoch 97/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9483 - loss: 0.1333 - val_accuracy: 0.9388 - val_loss: 0.2194 - learning_rate: 5.0000e-04
# Epoch 98/220
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9507 - loss: 0.1144
# Epoch 98: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9507 - loss: 0.1145 - val_accuracy: 0.9475 - val_loss: 0.2215 - learning_rate: 5.0000e-04
# Epoch 99/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9498 - loss: 0.1146 - val_accuracy: 0.9400 - val_loss: 0.2385 - learning_rate: 2.5000e-04
# Epoch 100/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9548 - loss: 0.1102 - val_accuracy: 0.9463 - val_loss: 0.2095 - learning_rate: 2.5000e-04
# Epoch 101/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9505 - loss: 0.1078 - val_accuracy: 0.9513 - val_loss: 0.2240 - learning_rate: 2.5000e-04
# Epoch 102/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9570 - loss: 0.1006 - val_accuracy: 0.9500 - val_loss: 0.2185 - learning_rate: 2.5000e-04
# Epoch 103/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9523 - loss: 0.1069 - val_accuracy: 0.9438 - val_loss: 0.2249 - learning_rate: 2.5000e-04
# Epoch 104/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9631 - loss: 0.0903 - val_accuracy: 0.9463 - val_loss: 0.2270 - learning_rate: 2.5000e-04
# Epoch 105/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9516 - loss: 0.1127 - val_accuracy: 0.9550 - val_loss: 0.2246 - learning_rate: 2.5000e-04
# Epoch 106/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9500 - loss: 0.1203 - val_accuracy: 0.9475 - val_loss: 0.2391 - learning_rate: 2.5000e-04
# Epoch 107/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9561 - loss: 0.1085 - val_accuracy: 0.9450 - val_loss: 0.2604 - learning_rate: 2.5000e-04
# Epoch 108/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9498 - loss: 0.1277 - val_accuracy: 0.9500 - val_loss: 0.2350 - learning_rate: 2.5000e-04
# Epoch 109/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9565 - loss: 0.1080 - val_accuracy: 0.9500 - val_loss: 0.2418 - learning_rate: 2.5000e-04
# Epoch 110/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9531 - loss: 0.1096 - val_accuracy: 0.9400 - val_loss: 0.2630 - learning_rate: 2.5000e-04
# Epoch 111/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9554 - loss: 0.1158 - val_accuracy: 0.9488 - val_loss: 0.2395 - learning_rate: 2.5000e-04
# Epoch 112/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9560 - loss: 0.1019 - val_accuracy: 0.9500 - val_loss: 0.2262 - learning_rate: 2.5000e-04
# Epoch 113/220
#  96/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9610 - loss: 0.1065
# Epoch 113: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9610 - loss: 0.1064 - val_accuracy: 0.9513 - val_loss: 0.2234 - learning_rate: 2.5000e-04
# Epoch 114/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9606 - loss: 0.1124 - val_accuracy: 0.9513 - val_loss: 0.2245 - learning_rate: 1.2500e-04
# Epoch 115/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9574 - loss: 0.1049 - val_accuracy: 0.9538 - val_loss: 0.2242 - learning_rate: 1.2500e-04
# Epoch 116/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9570 - loss: 0.1033 - val_accuracy: 0.9513 - val_loss: 0.2208 - learning_rate: 1.2500e-04
# Epoch 117/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9547 - loss: 0.1066 - val_accuracy: 0.9513 - val_loss: 0.2327 - learning_rate: 1.2500e-04
# Epoch 118/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9599 - loss: 0.1071 - val_accuracy: 0.9500 - val_loss: 0.2322 - learning_rate: 1.2500e-04
# Epoch 119/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9659 - loss: 0.0912 - val_accuracy: 0.9475 - val_loss: 0.2447 - learning_rate: 1.2500e-04
# Epoch 120/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9564 - loss: 0.1088 - val_accuracy: 0.9475 - val_loss: 0.2352 - learning_rate: 1.2500e-04
# Epoch 121/220
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9584 - loss: 0.1066
# Epoch 121: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9584 - loss: 0.1065 - val_accuracy: 0.9488 - val_loss: 0.2419 - learning_rate: 1.2500e-04
# Epoch 122/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9569 - loss: 0.1028 - val_accuracy: 0.9513 - val_loss: 0.2407 - learning_rate: 6.2500e-05
# Epoch 123/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9594 - loss: 0.1034 - val_accuracy: 0.9513 - val_loss: 0.2335 - learning_rate: 6.2500e-05
# Epoch 124/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9569 - loss: 0.0983 - val_accuracy: 0.9513 - val_loss: 0.2271 - learning_rate: 6.2500e-05
# Epoch 125/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9623 - loss: 0.0901 - val_accuracy: 0.9525 - val_loss: 0.2305 - learning_rate: 6.2500e-05
# Epoch 126/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9555 - loss: 0.1015 - val_accuracy: 0.9513 - val_loss: 0.2305 - learning_rate: 6.2500e-05
# Epoch 127/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9563 - loss: 0.1065 - val_accuracy: 0.9525 - val_loss: 0.2313 - learning_rate: 6.2500e-05
# Epoch 128/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9615 - loss: 0.0969 - val_accuracy: 0.9538 - val_loss: 0.2317 - learning_rate: 6.2500e-05
# Epoch 129/220
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9534 - loss: 0.1071
# Epoch 129: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9534 - loss: 0.1070 - val_accuracy: 0.9538 - val_loss: 0.2320 - learning_rate: 6.2500e-05
# Epoch 130/220
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9552 - loss: 0.0973 - val_accuracy: 0.9500 - val_loss: 0.2317 - learning_rate: 3.1250e-05
# Epoch 130: early stopping
# Restoring model weights from the end of the best epoch: 105.

# %% [markdown]
# ## 8. Evaluation

# %%
y_pred_prob_2d = lstm_model.predict(X_test_lstm, verbose=0)
y_pred_prob = y_pred_prob_2d[:, 1]  # probability of HD-positive class
y_pred = np.argmax(y_pred_prob_2d, axis=1)

acc = accuracy_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred_prob)
f1 = f1_score(y_test, y_pred)
mcc = matthews_corrcoef(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
tn, fp, fn, tp = cm.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
precision = tp / (tp + fp)

print('=' * 55)
print('LSTM — FINAL EVALUATION RESULTS')
print('=' * 55)
print(f'  Accuracy    : {acc * 100:.2f}%')
print(f'  AUC-ROC     : {auc:.4f}')
print(f'  F1-Score    : {f1:.4f}')
print(f'  MCC         : {mcc:.4f}')
print(f'  Sensitivity : {sensitivity:.4f}')
print(f'  Specificity : {specificity:.4f}')
print(f'  Precision   : {precision:.4f}')
print(f'\nConfusion Matrix:\n{cm}')
print(f'\n{classification_report(y_test, y_pred, target_names=["No HD", "HD"])}')
# Out:
# =======================================================
# LSTM — FINAL EVALUATION RESULTS
# =======================================================
#   Accuracy    : 94.60%
#   AUC-ROC     : 0.9882
#   F1-Score    : 0.9410
#   MCC         : 0.8912
#   Sensitivity : 0.9390
#   Specificity : 0.9519
#   Precision   : 0.9431
#
# Confusion Matrix:
# [[515  26]
#  [ 28 431]]
#
#               precision    recall  f1-score   support
#
#        No HD       0.95      0.95      0.95       541
#           HD       0.94      0.94      0.94       459
#
#     accuracy                           0.95      1000
#    macro avg       0.95      0.95      0.95      1000
# weighted avg       0.95      0.95      0.95      1000

# %% [markdown]
# ## 9. Results & Graphs

# %%
print('--- Accuracy Values ---')
print(f"Train Accuracy: {history.history['accuracy']}")
print(f"Validation Accuracy: {history.history['val_accuracy']}")
print('\n--- Loss Values ---')
print(f"Train Loss: {history.history['loss']}")
print(f"Validation Loss: {history.history['val_loss']}")

fig = plt.figure(figsize=(12, 18))
fig.suptitle('LSTM - Heart Disease Prediction Results',
             fontsize=15, fontweight='bold')
gs = gridspec.GridSpec(3, 2, figure=fig, hspace=0.40, wspace=0.35)

ax1 = fig.add_subplot(gs[0, 0])
ax1.plot(history.history['accuracy'],     label='Train', color='#378ADD')
ax1.plot(history.history['val_accuracy'], label='Val',   color='#D85A30', linestyle='--')
ax1.set_title('Accuracy Curves'); ax1.set_xlabel('Epoch'); ax1.set_ylabel('Accuracy')
ax1.legend(); ax1.grid(alpha=0.3)

ax3 = fig.add_subplot(gs[0, 1])
ax3.plot(history.history['loss'],     label='Train', color='#378ADD')
ax3.plot(history.history['val_loss'], label='Val',   color='#D85A30', linestyle='--')
ax3.set_title('Loss Curves'); ax3.set_xlabel('Epoch'); ax3.set_ylabel('Loss')
ax3.legend(); ax3.grid(alpha=0.3)

ax4 = fig.add_subplot(gs[1, 0])
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax4,
            xticklabels=['No HD', 'HD'], yticklabels=['No HD', 'HD'],
            linewidths=0.5, cbar=False)
ax4.set_title('Confusion Matrix'); ax4.set_ylabel('Actual'); ax4.set_xlabel('Predicted')

ax5 = fig.add_subplot(gs[2, :])   # ROC curve spans two columns
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
ax5.plot(fpr, tpr, color='#378ADD', lw=2, label=f'AUC = {auc:.4f}')
ax5.plot([0, 1], [0, 1], 'k--', lw=1)
ax5.fill_between(fpr, tpr, alpha=0.1, color='#378ADD')
ax5.set_title('ROC Curve'); ax5.set_xlabel('FPR'); ax5.set_ylabel('TPR')
ax5.legend(); ax5.grid(alpha=0.3)

plt.savefig('lstm_results.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved -> lstm_results.png')
# Out:
# --- Accuracy Values ---
# Train Accuracy: [0.6768749952316284, 0.6934375166893005, 0.6934375166893005, 0.6928125023841858, 0.6893749833106995, 0.7087500095367432, 0.692187488079071, 0.7053124904632568, 0.7265625, 0.721875011920929, 0.7409374713897705, 0.7481250166893005, 0.7534375190734863, 0.7612500190734863, 0.7537500262260437, 0.7603124976158142, 0.7721874713897705, 0.7790625095367432, 0.7774999737739563, 0.7934374809265137, 0.7925000190734863, 0.7984374761581421, 0.8100000023841858, 0.8125, 0.8187500238418579, 0.8221874833106995, 0.8365625143051147, 0.8318750262260437, 0.8453124761581421, 0.8521875143051147, 0.8475000262260437, 0.8543750047683716, 0.8553125262260437, 0.8543750047683716, 0.8665624856948853, 0.8668749928474426, 0.862500011920929, 0.8653125166893005, 0.8756250143051147, 0.8812500238418579, 0.8853124976158142, 0.8946874737739563, 0.8931249976158142, 0.8890625238418579, 0.8996875286102295, 0.9049999713897705, 0.9081249833106995, 0.9009374976158142, 0.9125000238418579, 0
# Saved -> lstm_results.png

# %%
# Threshold tuning on holdout probabilities
best_t, best_acc = 0.5, 0.0
for t in np.arange(0.30, 0.71, 0.01):
    preds_t = (y_pred_prob >= t).astype(int)
    acc_t = accuracy_score(y_test, preds_t)
    if acc_t > best_acc:
        best_acc = acc_t
        best_t = t

print(f'Best threshold: {best_t:.2f}')
print(f'Best accuracy : {best_acc * 100:.2f}%')

y_pred_opt = (y_pred_prob >= best_t).astype(int)
print('\nClassification report at best threshold:')
print(classification_report(y_test, y_pred_opt, target_names=['No HD', 'HD']))
# Out:
# Best threshold: 0.30
# Best accuracy : 94.90%
#
# Classification report at best threshold:
#               precision    recall  f1-score   support
#
#        No HD       0.96      0.95      0.95       541
#           HD       0.94      0.95      0.94       459
#
#     accuracy                           0.95      1000
#    macro avg       0.95      0.95      0.95      1000
# weighted avg       0.95      0.95      0.95      1000

# %%
# 10. Comparison Graph: LSTM vs Base Paper (All Requested Metrics)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Base paper values provided by user (in %)
base_paper_values = {
    'Accuracy': 94.65,
    'Precision': 94.65,
    'Sensitivity': 91.91,
    'MCC': 90.03,
    'Specificity': 94.41,
    'F1': 95.33
}

# Current model values from this notebook (converted to %)
model_values = {
    'Accuracy': float(acc * 100),
    'Precision': float(precision * 100),
    'Sensitivity': float(sensitivity * 100),
    'MCC': float(mcc * 100),
    'Specificity': float(specificity * 100),
    'F1': float(f1 * 100)
}

metric_order = ['Accuracy', 'Precision', 'AUC', 'Sensitivity', 'MCC', 'Specificity', 'F1']
metric_order = [m for m in metric_order if m in base_paper_values and m in model_values]

compare_df = pd.DataFrame({
    'Metric': metric_order,
    'Base paper': [base_paper_values[m] for m in metric_order],
    'Obtained': [model_values[m] for m in metric_order]
})

x = np.arange(len(compare_df))
width = 0.35

fig, ax = plt.subplots(figsize=(11, 5.5))
ax.bar(x - width/2, compare_df['Base paper'], width=width, color='#6f7780', label='Base paper')
ax.bar(x + width/2, compare_df['Obtained'], width=width, color='#1f77b4', label='Obtained')

ax.set_xticks(x)
ax.set_xticklabels(compare_df['Metric'], rotation=15)
ax.set_ylabel('Score (%)')
ax.set_title('LSTM - Base Paper vs Obtained Metrics')
ax.set_ylim(0, 100)
ax.grid(axis='y', alpha=0.25)
ax.legend(loc='upper center')

plt.tight_layout()
plt.show()

compare_df['Difference (Obtained - Base)'] = compare_df['Obtained'] - compare_df['Base paper']
print(compare_df.to_string(index=False))
# Out:
#      Metric  Base paper  Obtained  Difference (Obtained - Base)
#    Accuracy       94.65 94.600000                     -0.050000
#   Precision       94.65 94.310722                     -0.339278
# Sensitivity       91.91 93.899782                      1.989782
#         MCC       90.03 89.124021                     -0.905979
# Specificity       94.41 95.194085                      0.784085
#          F1       95.33 94.104803                     -1.225197
